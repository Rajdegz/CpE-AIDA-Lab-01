# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajdegz/CpE-AIDA-Lab-01/blob/main/58021_Dataset_Exploration_DDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pov_country = pd.read_csv('wb_subnational_poverty_data.csv')
pov_country
# Out:
#                                          indicator_name indicator_code  \
# 0     Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 1     Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 2     Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 3     Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 4     Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# ...                                                 ...            ...
# 3626  Poverty headcount ratio at urban poverty line ...    SI.POV.URHC
# 3627  Poverty headcount ratio at urban poverty line ...    SI.POV.URHC
# 3628  Poverty headcount ratio at urban poverty line ...    SI.POV.URHC
# 3629  Poverty headcount ratio at urban poverty line ...    SI.POV.URHC
# 3630  Poverty headcount ratio at urban poverty line ...    SI.POV.URHC
#
#                             country_name  \
# 0                             Mozambique
# ...

# %%
pov_country.head()
# Out:
#                                       indicator_name indicator_code  \
# 0  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 1  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 2  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 3  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 4  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
#
#                country_name                          country_code  value  \
# 0                Mozambique                                   MOZ   69.4
# 1  Mozambique, Cabo Delgado  MOZ_Cabo_Delgado_MZ.CD_2112.1_MOZ001   57.4
# 2          Mozambique, Gaza          MOZ_Gaza_MZ.GA_2113.1_MOZ002   64.6
# 3     Mozambique, Inhambane     MOZ_Inhambane_MZ.IN_2114.1_MOZ003   82.6
# 4        Mozambique, Manica        MOZ_Manica_MZ.MN_2115.1_MOZ004   62.6
#
#          year
# 0  1996-01-01
# 1  1996-01-01
# 2  1996-01-01
# 3  1996-01-01
# 4  1996-01-01

# %%
pov_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3631 entries, 0 to 3630
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   indicator_name  3631 non-null   object
#  1   indicator_code  3631 non-null   object
#  2   country_name    3631 non-null   object
#  3   country_code    3631 non-null   object
#  4   value           3631 non-null   float64
#  5   year            3631 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 170.3+ KB

# %%
pov_country.describe()
# Out:
#              value
# count  3631.000000
# mean     29.899331
# std      19.506134
# min       0.000000
# 25%      13.694033
# 50%      25.300000
# 75%      43.700000
# max      93.600000

# %%
new_pov_country = pov_country.sort_values ('value', ascending = False)
new_pov_country
# Out:
#                                          indicator_name indicator_code  \
# 691   Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 344   Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 2669  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 1831  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 2803  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# ...                                                 ...            ...
# 2961  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 2094  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 2280  Poverty headcount ratio at national poverty li...    SI.POV.NAHC
# 3562  Poverty headcount ratio at rural poverty line ...    SI.POV.RUHC
# 3319  Poverty headcount ratio at rural poverty line ...    SI.POV.RUHC
#
#                              country_name  \
# 691            Congo, Dem. Rep., Equateur
# ...
